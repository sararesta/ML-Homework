# %%
# Run this code to make Jupyter print every
# printable statement and not just the last one
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# To visualize the data
import matplotlib.pyplot as plt

# Generic libraries
import seaborn as sns
import pandas as pd
import numpy as np

# Regression models
import sklearn
import scipy
from scipy.stats import t
import sklearn
from sklearn.model_selection import train_test_split #split the data into training and test
from sklearn.linear_model import LinearRegression #linear regression
from sklearn.preprocessing import PolynomialFeatures #for polynomial regression
from sklearn.metrics import r2_score, mean_squared_error

# 5-folds crossvalidation
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Regression

# %% [markdown]
# Import the datasets (for this step we need only the training set)

# %%
training_set = pd.read_csv("data/training_set_online_shoppers_intention.csv")

# %% [markdown]
# We set all the categorical types as category $\rightarrow$ non so se sia davvero utile o no, magari lo teniamo solo per la heatmap, l'ho tolto perché così facendo c'erano dei problemi con la riassegnazione della categoria other: TypeError: Cannot setitem on a Categorical with a new category (Others), set the categories first
#
# Ho pensato che tanto poi le trasformiamo tutte in binarie, quindi fa lo stesso. Magari poi ne creiamo una copia se decidiamo di fare visual inspection sul training.

# %% [markdown]
# Here we group the categories with the lowest number of elements into 'others'. Since these categories doesn't have a significant number of elements we don't expect them to be significant. Giving too many importance to them may lead to overfitting problems (di questa cosa non sono sicura ed è anche scritta in un inglese che fa pena)

# %%
training_set['Weekend'] = np.where(training_set['Weekend']=='False',1,0)

# Split categorical variables
months = pd.get_dummies(training_set.Month, prefix='Month')
regions = pd.get_dummies(training_set.Region, prefix='Region')
browser = pd.get_dummies(training_set.Browser, prefix='Browser')
traffic_type = pd.get_dummies(training_set.TrafficType, prefix='TrafficType')
os = pd.get_dummies(training_set.OperatingSystems, prefix='OperatingSystems')
visitor = pd.get_dummies(training_set.VisitorType, prefix='VisitorType')

# %% [markdown]
# Here we replace the categorical features with the dummies variables obtaining binary features

# %%
training_set = training_set.drop(['Unnamed: 0','Month','Region','Browser','TrafficType','OperatingSystems','VisitorType'], axis=1).join([months,regions,browser,traffic_type,os,visitor])
training_set.shape
# Out:
# (9248, 74)

# %%
# split the training set to separate the rows with missing values
mask = training_set['ExitRates'].isna()
training_set_missing = training_set[mask]
#training_set_missing.head()
training_set_no_missing = training_set[mask==False]
#training_set_no_missing.head()

# %%
X_all_features = list(np.delete(training_set.columns.values, [np.where(training_set.columns.values=='ExitRates'),np.where(training_set.columns.values=='Revenue')], axis=None))
X = training_set_no_missing[X_all_features].to_numpy()
y = training_set_no_missing['ExitRates'].to_numpy()

# %% [markdown]
# Now we split the training data to obtain a train and a test set to train the regression model and to compute the performance scores. QUI ALLA FINE HO CAMBIATO IL SEED PER FAR SI' CHE NON AVESSIMO UN TEST SCORE MIGLIORE DI TRAIN SCORE

# %%
#splitting data
test_size = 0.3
test_seed = 40
# Split X and y into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=test_seed)
print("X_train.shape ", X_train.shape)
print("X_test.shape ", X_test.shape)
# Out:
# X_train.shape  (4526, 72)
# X_test.shape  (1940, 72)

# %% [markdown]
# Now we fit different polynomial regression models

# %% [markdown]
# ## Hyperparameter selection
# We want to know which is the best degree for our polynome. So we fit regression model with different grades and then we use 5-fold cv to evaluate their performances

# %%
r2_scorer = make_scorer(r2_score, greater_is_better=True)

degree = list(range(1,3))
val_scores = np.zeros(len(degree))
# Validation
for i, d in enumerate(degree):
    # build the model
    model = Pipeline([('poly', PolynomialFeatures(degree=d, include_bias=False)),
                      ('linear', LinearRegression(fit_intercept=True))])
    scores = cross_val_score(model, X_train, y_train, scoring=r2_scorer, cv=5)
    val_scores[i] = np.mean(scores)

# Identifies which is the best degree
best_model_idx = np.argmax(val_scores)
best_degree = degree[best_model_idx]
# And the corresponding (best) validation score
best_val_score = val_scores[best_model_idx]
print("Best degree: ", best_degree,
      "\nVal score: ", best_val_score)
    
    
# Train again the Pipeline using the best parameter and the whole training set
model = Pipeline([('poly', PolynomialFeatures(degree=best_degree, include_bias=False)),
                  ('linear', LinearRegression(fit_intercept=True))])
# Note: we train on X_train_small + X_val
model = model.fit(np.concatenate([X_train]), np.concatenate([y_train]))
y_predict = model.predict(X_test)
test_score = r2_score(y_test, y_predict)

print("Train R2 score ", r2_score(y_train, model.predict(X_train)))
print("Train MSE score ", mean_squared_error(y_train, model.predict(X_train)))

print("Test R2 score ", r2_score(y_test, model.predict(X_test)))
print("Test MSE score ", mean_squared_error(y_test, model.predict(X_test)))

print("Test score:", test_score)
# Out:
# Best degree:  1
# Val score:  0.8686325114038974
# Train R2 score  0.8722813637103644
# Train MSE score  0.0002997774220603436
# Test R2 score  0.839346267180995
# Test MSE score  0.0003622039794715234
# Test score: 0.839346267180995

# %%
X2 = training_set_missing[X_all_features].to_numpy()
y_predict2 = model.predict(X2)
print(y_predict2)
# Out:
# [0.04028793 0.01876095 0.0379217  ... 0.04039319 0.02621844 0.01401199]

# %% [markdown]
# Now we plot the residuals. Except for some outliers, they show an almost random distribution centered in zero.

# %%
residuals = y_test-y_predict
plt.scatter(y_predict,residuals)
plt.show()

# %%
# Convert back from numpy arrays to data frames
X_train_pd = pd.DataFrame(X_train, columns=X_all_features)
X_test_pd = pd.DataFrame(X_test, columns=X_all_features)

# %% [markdown]
# ## Forward stepwise selection to find the best subset of features

# %%
import itertools
def get_subsets(X_pd, dim):
    feature_names = X_pd.columns.tolist()
    # Compute all possibile combinations of 'dim' values
    subset_names = itertools.combinations(feature_names, dim) # list of list of names [[name of first candidate, ...], [...]]
    # Convert names into datasets
    data_subsets = [X_pd[list(fnames)] for fnames in subset_names]
    return data_subsets

#subsets = get_subsets(X_train_pd, 3)
#subsets[0].head() # training set of the first subset
#subsets[1].head() # training set of the second subset

# %%
def rss(y_true, y_pred):
    # First we make sure the shapes are the same
    y_true = y_true.reshape(y_pred.shape)
    return np.sum((y_true - y_pred) ** 2)

# %%
def estimate_sigma(Xtrain_pd, ytrain):
    # Sigma is usually estimated using the model with all features
    n, p = Xtrain_pd.shape
    model = LinearRegression(fit_intercept=True)
    model.fit(Xtrain_pd, ytrain)
    y_pred = model.predict(Xtrain_pd)
    RSS = rss(y_pred, ytrain)
    RSE = np.sqrt(RSS / (n-p))
    return RSE

def cp(y_pred, y_true, n, d, sigma):
    sigma2 = sigma**2
    return (rss(y_pred, y_true) + 2*d*sigma2) / n

def aic(y_pred, y_true, n, d, sigma):
    sigma2 = sigma**2
    return (rss(y_pred, y_true) + 2*d*sigma2) / (n*sigma2)

def bic(y_pred, y_true, n, d, sigma):
    sigma2 = sigma**2
    return (rss(y_pred, y_true) + np.log(n)*d*sigma2) / (n*sigma2)

def adj_r2(y_pred, y_true, n, d, sigma):
    sigma2 = sigma**2
    RSS = rss(y_pred, y_true)
    TSS = tss(y_true)
    return 1 - (RSS/(n-d-1)) / (TSS/(n-1))

# %%
def get_sigma_scorer(metric, sigma):
    def scorer(model, X, y):
        n, d = X.shape
        y_pred = model.predict(X)
        return metric(y_pred, y, n, d, sigma)
    
    return scorer

sigma = estimate_sigma(X_train_pd, y_train)
'''subset_selection(X_train_pd, y_train, X_test_pd, y_test,
                 get_evaluator(make_scorer(rss)), np.argmin, # 2.
                 get_evaluator(get_sigma_scorer(bic, sigma)), np.argmin, # 3.
                 get_evaluator(make_scorer(mean_squared_error)), np.argmin, # test
                 candidates_scorer_name="RSS",
                 subsets_scorer_name="BIC",
                 verbose=True)'''
# Out:
# 'subset_selection(X_train_pd, y_train, X_test_pd, y_test,\n                 get_evaluator(make_scorer(rss)), np.argmin, # 2.\n                 get_evaluator(get_sigma_scorer(bic, sigma)), np.argmin, # 3.\n                 get_evaluator(make_scorer(mean_squared_error)), np.argmin, # test\n                 candidates_scorer_name="RSS",\n                 subsets_scorer_name="BIC",\n                 verbose=True)'

# %%
def get_evaluator(scorer):
    def evaluator(model, X, y, trained=False):
        if not trained:
            model = model.fit(X, y)
        score = scorer(model, X, y)
        return model, score
    return evaluator

# %%
from sklearn.dummy import DummyRegressor

def forward_selection(Xtrain_pd, ytrain, Xtest_pd, ytest,
                      candidates_evaluator, candidates_argbest, # Metric to be used at 2.b
                      subsets_evaluator, subsets_argbest,       # Metric to be used at 3
                      test_evaluator=None, test_argbest=None,
                      candidates_scorer_name=None,  # Name of 2. figure
                      subsets_scorer_name=None,     # Name of 3. figure
                      verbose=True, weight_step3=0):   
    test_evaluator = subsets_evaluator if not test_evaluator else test_evaluator
    test_argbest = subsets_argbest if not test_argbest else test_argbest
    
    # Global variable init
    # ====================
    num_features = Xtrain_pd.shape[-1]
    best_candidate_metric = []
    # subsets_* are lists containing one value for each Mk model (the best of the Mk candidates)
    subsets_test = []
    subsets_metric = []        # The best metric of each subset of dimension 'dim'
    subsets_best_features = [] # The best features combination in each subset of dimension 'dim'
    # A figure to keep track of candidates scores in each Mk subset
    plt.figure()
    candidate_fig = plt.subplot(111) # A global matplotlib figure
    num_evaluations = 0        # A conter to keep track of the total number of trials
    
    selected_features = []  # <------ !! We keep track of selected features !!
    all_features = Xtrain_pd.columns
    
    
    # 1. Train M0
    # ===========
    model = DummyRegressor()
    # Compute (2.b) metrics
    model, score = candidates_evaluator(model, Xtrain_pd[[]], ytrain)
    best_candidate_metric.append(score)
    subsets_best_features.append([])
    _ = candidate_fig.scatter([0], [score], color="b")
    # Compute metric for step 3.
    _, score = subsets_evaluator(model, Xtrain_pd[[]], ytrain, trained=True)
    subsets_metric.append(score)
    _, score = test_evaluator(model, Xtrain_pd[[]], ytrain, trained=True)
    subsets_test.append(score)
    
    # 2. Evaluate all Mk candidates with
    #    k=0...P features
    # =========================================
    #!! The loop condition is slightly changed
    #!! How many iterations we need to perform?
    for dim in range(num_features):
        candidate_metrics = [] # Keep track of candidates metrics. Will be used to select the best
        candidate_models = []  # Keep track of candidates trained models
        
        # 2.a Given the previous Mk model, test remaining
        # features and select the one providing the best
        # performance increment
        # ===============================================
        remaining_features = Xtrain_pd.columns.difference(selected_features)
        
        for new_column in remaining_features:
            Xtrain_sub = Xtrain_pd[selected_features+[new_column]].to_numpy()
            model = LinearRegression(fit_intercept=True)
            model, score = candidates_evaluator(model, Xtrain_sub, ytrain)
            candidate_models.append(model)
            candidate_metrics.append(score)
            num_evaluations += 1
            
        _ = candidate_fig.scatter([Xtrain_sub.shape[-1]]*len(candidate_metrics), candidate_metrics,
                                  color="b")
            
        # 2.b Select the best candidate in (2.a)
        # ===============================================
        idx_best_candidate = candidates_argbest(candidate_metrics)
        #!!! Update selected feature
        # ==========================
        selected_features.append(remaining_features[idx_best_candidate])
        # Save best candidate features
        best_candidate_metric.append(candidate_metrics[idx_best_candidate])
        best_features = selected_features.copy()
        subsets_best_features.append(best_features)
        
        # Compute metric for step 3.
        best_subset_model = candidate_models[idx_best_candidate]
        best_subset_Xtrain = Xtrain_pd[best_features].to_numpy()
        _, score = subsets_evaluator(best_subset_model, best_subset_Xtrain, ytrain, trained=True)
        subsets_metric.append(score)
        best_subset_Xtest = Xtest_pd[best_features].to_numpy()
        _, score_test = test_evaluator(best_subset_model, best_subset_Xtest, ytest, trained=True)
        subsets_test.append(score_test)
        num_evaluations += weight_step3 
        
        if verbose:
            print("............")
            print("Best model (M{}) with {} features: {}".format(dim, dim+1, best_features))
            print("M{} subset score (3.): {}".format(dim, score))
        
    # 3. Among all best candidates with increasing number
    #    of features, select the best one
    # ===================================================
    best_subset_idx = subsets_argbest(subsets_metric)
    best_features = subsets_best_features[best_subset_idx]
    
    if verbose:
        print("\n\nBest configuration has {} features".format(best_subset_idx))
        print("Features: {}".format(subsets_best_features[best_subset_idx]))
        print("Total number of trained models:", num_evaluations)
    
    # Complete the subsets_fig figure by plotting
    # a line connecting all best candidate score
    best_candidate_score_idx = candidates_argbest(best_candidate_metric)
    _ = candidate_fig.plot(range(len(best_candidate_metric)), best_candidate_metric)
    _ = candidate_fig.scatter(best_candidate_score_idx, best_candidate_metric[best_candidate_score_idx],
                              marker='X', label="Best", color="r")
    candidate_fig.set_title(candidates_scorer_name)
    candidate_fig.legend()
    
    # Plot a figure to show how te 3. metric evolves
    plt.figure()
    subsets_fig = plt.subplot(111)
    _ = subsets_fig.plot(range(len(subsets_metric)), subsets_metric, label="Selection (3.) scores")
    _ = subsets_fig.scatter(best_subset_idx, subsets_metric[best_subset_idx],
                              marker='X', label="Best (3.) score", color="r")
    best_test_score_idx = test_argbest(subsets_test)
    _ = subsets_fig.plot(range(len(subsets_test)), subsets_test, label="Test scores")
    _ = subsets_fig.scatter(best_test_score_idx, subsets_test[best_test_score_idx],
                              marker='X', label="Best test score", color="y")
    subsets_fig.set_title(subsets_scorer_name)
    subsets_fig.legend()

# %%
forward_selection(X_train_pd, y_train, X_test_pd, y_test,
                  get_evaluator(make_scorer(r2_score)), np.argmax, # 2.
                  get_evaluator(get_sigma_scorer(bic, sigma)), np.argmin, # 3.
                  get_evaluator(make_scorer(mean_squared_error)), np.argmin, # test
                  candidates_scorer_name="R^2",
                  subsets_scorer_name="BIC",
                  verbose=True)
# Out:
# ............
# Best model (M0) with 1 features: ['BounceRates']
# M0 subset score (3.): 1.2233835855859694
# ............
# Best model (M1) with 2 features: ['BounceRates', 'Administrative']
# M1 subset score (3.): 1.1306554035865959
# ............
# Best model (M2) with 3 features: ['BounceRates', 'Administrative', 'ProductRelated']
# M2 subset score (3.): 1.0951818453721596
# ............
# Best model (M3) with 4 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor']
# M3 subset score (3.): 1.0558958389136568
# ............
# Best model (M4) with 5 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues']
# M4 subset score (3.): 1.0355087191428791
# ............
# Best model (M5) with 6 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2']
# M5 subset score (3.): 1.0286198947404046
# ............
# Best model (M6) with 7 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2']
# M6 subset score (3.): 1.0228974115965292
# ............
# Best model (M7) with 8 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4']
# M7 subset score (3.): 1.0195133517257904
# ............
# Best model (M8) with 9 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay']
# M8 subset score (3.): 1.018291492620153
# ............
# Best model (M9) with 10 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June']
# M9 subset score (3.): 1.017583954161686
# ............
# Best model (M10) with 11 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1']
# M10 subset score (3.): 1.0178649098726076
# ............
# Best model (M11) with 12 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10']
# M11 subset score (3.): 1.0188934947330854
# ............
# Best model (M12) with 13 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12']
# M12 subset score (3.): 1.0199698589694597
# ............
# Best model (M13) with 14 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec']
# M13 subset score (3.): 1.021044323348295
# ............
# Best model (M14) with 15 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8']
# M14 subset score (3.): 1.022201757981916
# ............
# Best model (M15) with 16 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other']
# M15 subset score (3.): 1.0221056802577224
# ............
# Best model (M16) with 17 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4']
# M16 subset score (3.): 1.0232894454520993
# ............
# Best model (M17) with 18 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7']
# M17 subset score (3.): 1.0245057520133996
# ............
# Best model (M18) with 19 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9']
# M18 subset score (3.): 1.0258059969788595
# ............
# Best model (M19) with 20 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3']
# M19 subset score (3.): 1.0270083419855434
# ............
# Best model (M20) with 21 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3']
# M20 subset score (3.): 1.0283377690033717
# ............
# Best model (M21) with 22 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16']
# M21 subset score (3.): 1.0296933748151371
# ............
# Best model (M22) with 23 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19']
# M22 subset score (3.): 1.031055898483868
# ............
# Best model (M23) with 24 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12']
# M23 subset score (3.): 1.0324824767927816
# ............
# Best model (M24) with 25 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov']
# M24 subset score (3.): 1.0340040078846524
# ............
# Best model (M25) with 26 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14']
# M25 subset score (3.): 1.035569826995387
# ............
# Best model (M26) with 27 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13']
# M26 subset score (3.): 1.0371439101935973
# ............
# Best model (M27) with 28 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18']
# M27 subset score (3.): 1.0387234283306972
# ............
# Best model (M28) with 29 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6']
# M28 subset score (3.): 1.0403424755771447
# ............
# Best model (M29) with 30 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul']
# M29 subset score (3.): 1.0420168027419958
# ............
# Best model (M30) with 31 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7']
# M30 subset score (3.): 1.0436861156092776
# ............
# Best model (M31) with 32 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10']
# M31 subset score (3.): 1.0453734620841264
# ............
# Best model (M32) with 33 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1']
# M32 subset score (3.): 1.0470579932392534
# ............
# Best model (M33) with 34 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13']
# M33 subset score (3.): 1.0487548407591565
# ............
# Best model (M34) with 35 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3']
# M34 subset score (3.): 1.0503636254962045
# ............
# Best model (M35) with 36 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb']
# M35 subset score (3.): 1.0520881291200828
# ............
# Best model (M36) with 37 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug']
# M36 subset score (3.): 1.0538265150424044
# ............
# Best model (M37) with 38 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3']
# M37 subset score (3.): 1.0555726499763658
# ............
# Best model (M38) with 39 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration']
# M38 subset score (3.): 1.0573358181840564
# ............
# Best model (M39) with 40 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration']
# M39 subset score (3.): 1.059081778868133
# ............
# Best model (M40) with 41 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6']
# M40 subset score (3.): 1.0608602941178504
# ............
# Best model (M41) with 42 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4']
# M41 subset score (3.): 1.0626413842104134
# ............
# Best model (M42) with 43 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15']
# M42 subset score (3.): 1.0644287017525853
# ............
# Best model (M43) with 44 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1']
# M43 subset score (3.): 1.0662218561088532
# ............
# Best model (M44) with 45 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct']
# M44 subset score (3.): 1.0680314404947444
# ............
# Best model (M45) with 46 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8']
# M45 subset score (3.): 1.0698544291814525
# ............
# Best model (M46) with 47 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep']
# M46 subset score (3.): 1.0716811934289856
# ............
# Best model (M47) with 48 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20']
# M47 subset score (3.): 1.0735096153212187
# ............
# Best model (M48) with 49 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational']
# M48 subset score (3.): 1.0753431587812903
# ............
# Best model (M49) with 50 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration']
# M49 subset score (3.): 1.0771714853417833
# ............
# Best model (M50) with 51 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8']
# M50 subset score (3.): 1.0790122353279539
# ............
# Best model (M51) with 52 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8']
# M51 subset score (3.): 1.0808545640351759
# ............
# Best model (M52) with 53 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5']
# M52 subset score (3.): 1.0826981196281313
# ............
# Best model (M53) with 54 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9']
# M53 subset score (3.): 1.0845491986463087
# ............
# Best model (M54) with 55 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1']
# M54 subset score (3.): 1.0863977760804628
# ............
# Best model (M55) with 56 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar']
# M55 subset score (3.): 1.0882515995489623
# ............
# Best model (M56) with 57 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5']
# M56 subset score (3.): 1.0901067219091007
# ............
# Best model (M57) with 58 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11']
# M57 subset score (3.): 1.091963570700417
# ............
# Best model (M58) with 59 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7']
# M58 subset score (3.): 1.093822431550067
# ............
# Best model (M59) with 60 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6']
# M59 subset score (3.): 1.095681902402398
# ............
# Best model (M60) with 61 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11']
# M60 subset score (3.): 1.0975416674873
# ............
# Best model (M61) with 62 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4']
# M61 subset score (3.): 1.0994014369715341
# ............
# Best model (M62) with 63 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2']
# M62 subset score (3.): 1.1012612485749425
# ............
# Best model (M63) with 64 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2']
# M63 subset score (3.): 1.1031210792921746
# ............
# Best model (M64) with 65 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May']
# M64 subset score (3.): 1.1049809100094075
# ............
# Best model (M65) with 66 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5']
# M65 subset score (3.): 1.1068407407266394
# ............
# Best model (M66) with 67 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5', 'OperatingSystems_7']
# M66 subset score (3.): 1.1087005714438718
# ............
# Best model (M67) with 68 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5', 'OperatingSystems_7', 'Region_5']
# M67 subset score (3.): 1.110560402161104
# ............
# Best model (M68) with 69 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5', 'OperatingSystems_7', 'Region_5', 'TrafficType_17']
# M68 subset score (3.): 1.1124202328783366
# ............
# Best model (M69) with 70 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5', 'OperatingSystems_7', 'Region_5', 'TrafficType_17', 'TrafficType_6']
# M69 subset score (3.): 1.1142800635955687
# ............
# Best model (M70) with 71 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5', 'OperatingSystems_7', 'Region_5', 'TrafficType_17', 'TrafficType_6', 'VisitorType_Returning_Visitor']
# M70 subset score (3.): 1.116139894312801
# ............
# Best model (M71) with 72 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5', 'OperatingSystems_7', 'Region_5', 'TrafficType_17', 'TrafficType_6', 'VisitorType_Returning_Visitor', 'Weekend']
# M71 subset score (3.): 1.1179997250300335
#
#
# Best configuration has 10 features
# Features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June']
# Total number of trained models: 2628

# %% [markdown]
# Now we try to search for the best polynomial model with our reduced set of features.

# %%
X_features_best = ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'SpecialDay', 'TrafficType_4', 'Month_June']

X = training_set_no_missing[X_features_best].to_numpy()
y = training_set_no_missing['ExitRates'].to_numpy()

#splitting data
test_size = 0.3
test_seed = 40
# Split X and y into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=test_seed)
print("X_train.shape ", X_train.shape)
print("X_test.shape ", X_test.shape)


degree = list(range(1,3))
val_scores = np.zeros(len(degree))
# Validation
for i, d in enumerate(degree):
    model = Pipeline([('poly', PolynomialFeatures(degree=d, include_bias=False)),
                      ('linear', LinearRegression(fit_intercept=True))])
    scores = cross_val_score(model, X_train, y_train, scoring=r2_scorer, cv=5)
    val_scores[i] = np.mean(scores)

# Identifies which is the best degree
best_model_idx = np.argmax(val_scores)
best_degree = degree[best_model_idx]
# And the corresponding (best) validation score
best_val_score = val_scores[best_model_idx]
print("Best degree: ", best_degree,
      "\nVal score: ", best_val_score)
    
    
# Train again the Pipeline using the best parameter and the whole training set
model = Pipeline([('poly', PolynomialFeatures(degree=best_degree, include_bias=False)),
                  ('linear', LinearRegression(fit_intercept=True))])
# Note: we train on X_train_small + X_val
model = model.fit(np.concatenate([X_train]), np.concatenate([y_train]))
y_predict = model.predict(X_test)
test_score = r2_score(y_test, y_predict)

print("Test score:", test_score)
# Out:
# X_train.shape  (4526, 10)
# X_test.shape  (1940, 10)
# Best degree:  2
# Val score:  0.8782758170004822
# Test score: 0.8562982595434785

# %%
X2 = training_set_missing[X_features_best].to_numpy()
y_predict2 = model.predict(X2)
file = open("ExitRates.txt",'w')
for y in y_predict2:
    file.write(str(y))
    file.write('\n')
file.close()
# Out:
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 21
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 21
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 21
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 17
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 21
# 1
# 21
# 1
# 18
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 21
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 21
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 21
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 21
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 21
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 21
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 21
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 17
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 23
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 21
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 21
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 18
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 21
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 17
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 18
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 23
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 21
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 17
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 21
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 22
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 17
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 21
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 21
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 21
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 17
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 21
# 1
# 20
# 1
# 20
# 1
# 21
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 21
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 15
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 17
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 22
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 22
# 1
# 20
# 1
# 16
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 21
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 21
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 22
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 17
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 21
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 17
# 1
# 18
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 21
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 21
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 22
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 17
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 22
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 21
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 22
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 22
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 17
# 1
# 20
# 1
# 21
# 1
# 21
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 21
# 1
# 21
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 22
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 22
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 18
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 18
# 1
# 18
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 20
# 1
# 19
# 1
# 19
# 1
# 20
# 1
# 19
# 1
# 20
# 1
# 20
# 1

# %% [markdown]
# ## Forward stepwise selection and crossvalidation

# %%
def get_val_evaluator(scorer, val_size=0.3):
    def evaluator(model, X, y, trained=False):
        X_train_small, X_val, y_train_small, y_val = train_test_split(X, y, 
                                                                      test_size=val_size,
                                                                      random_state=mpg_test_seed)
        
        if not trained:
            model = model.fit(X_train_small, y_train_small)
        score = scorer(model, X_val, y_val) 
        
        return model, score
    
    return evaluator

def get_cv_evaluator(scorer, cv=3):
    def evaluator(model, X, y, trained=False):            
        scores = cross_val_score(model, X, y, scoring=scorer, cv=cv)
        if not trained:
            model = model.fit(X, y)
        return model, np.mean(scores)
    
    return evaluator


cv = 10
sigma = estimate_sigma(X_train_pd, y_train)
forward_selection(X_train_pd, y_train, X_test_pd, y_test,
                  get_evaluator(make_scorer(r2_score)), np.argmax, # 2.b
                  # Use either 5-fold CV or (1-fold cross) validation to 
                  # estimate the test R^2 error at step (3.) of the algorithm
                  get_cv_evaluator(make_scorer(r2_score), cv=cv), np.argmax, # 3.
                  get_evaluator(make_scorer(r2_score)), np.argmax, # test
                  candidates_scorer_name="cv(R^2)",
                  subsets_scorer_name="cv(R^2)",
                  verbose=True, weight_step3=10)
# Out:
# ............
# Best model (M0) with 1 features: ['BounceRates']
# M0 subset score (3.): 0.8399691408563429
# ............
# Best model (M1) with 2 features: ['BounceRates', 'Administrative']
# M1 subset score (3.): 0.8522514554087939
# ............
# Best model (M2) with 3 features: ['BounceRates', 'Administrative', 'ProductRelated']
# M2 subset score (3.): 0.8570476747510881
# ............
# Best model (M3) with 4 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor']
# M3 subset score (3.): 0.8623941454073247
# ............
# Best model (M4) with 5 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues']
# M4 subset score (3.): 0.8652463418895742
# ............
# Best model (M5) with 6 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2']
# M5 subset score (3.): 0.8663268036117963
# ............
# Best model (M6) with 7 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2']
# M6 subset score (3.): 0.8673080009794077
# ............
# Best model (M7) with 8 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4']
# M7 subset score (3.): 0.8679126428564736
# ............
# Best model (M8) with 9 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay']
# M8 subset score (3.): 0.8682390715693356
# ............
# Best model (M9) with 10 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June']
# M9 subset score (3.): 0.8685678590023247
# ............
# Best model (M10) with 11 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1']
# M10 subset score (3.): 0.8687017669545607
# ............
# Best model (M11) with 12 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10']
# M11 subset score (3.): 0.8687813057301976
# ............
# Best model (M12) with 13 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12']
# M12 subset score (3.): 0.8687849733774984
# ............
# Best model (M13) with 14 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec']
# M13 subset score (3.): 0.8688257963130436
# ............
# Best model (M14) with 15 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8']
# M14 subset score (3.): 0.8688585698301076
# ............
# Best model (M15) with 16 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other']
# M15 subset score (3.): 0.8689712737692924
# ............
# Best model (M16) with 17 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4']
# M16 subset score (3.): 0.8690334452471896
# ............
# Best model (M17) with 18 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7']
# M17 subset score (3.): 0.8690379215228875
# ............
# Best model (M18) with 19 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9']
# M18 subset score (3.): 0.8690372283799711
# ............
# Best model (M19) with 20 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3']
# M19 subset score (3.): 0.8691074172820024
# ............
# Best model (M20) with 21 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3']
# M20 subset score (3.): 0.8690858125874346
# ............
# Best model (M21) with 22 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16']
# M21 subset score (3.): 0.8690979061811008
# ............
# Best model (M22) with 23 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19']
# M22 subset score (3.): 0.8691541865430942
# ............
# Best model (M23) with 24 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12']
# M23 subset score (3.): 0.8692056068683321
# ............
# Best model (M24) with 25 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov']
# M24 subset score (3.): 0.8691729333351234
# ............
# Best model (M25) with 26 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14']
# M25 subset score (3.): 0.8691885186944903
# ............
# Best model (M26) with 27 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13']
# M26 subset score (3.): 0.8691852160722995
# ............
# Best model (M27) with 28 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18']
# M27 subset score (3.): 0.8691867713316503
# ............
# Best model (M28) with 29 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6']
# M28 subset score (3.): 0.8691940881775547
# ............
# Best model (M29) with 30 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul']
# M29 subset score (3.): 0.8691543442680325
# ............
# Best model (M30) with 31 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7']
# M30 subset score (3.): 0.869170651405738
# ............
# Best model (M31) with 32 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10']
# M31 subset score (3.): 0.8690879486693659
# ............
# Best model (M32) with 33 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1']
# M32 subset score (3.): 0.8690713854024119
# ............
# Best model (M33) with 34 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13']
# M33 subset score (3.): 0.8690492980162864
# ............
# Best model (M34) with 35 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3']
# M34 subset score (3.): 0.8690574625090235
# ............
# Best model (M35) with 36 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb']
# M35 subset score (3.): 0.8690384679036864
# ............
# Best model (M36) with 37 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug']
# M36 subset score (3.): 0.8690119916989764
# ............
# Best model (M37) with 38 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3']
# M37 subset score (3.): 0.8690162037838697
# ............
# Best model (M38) with 39 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration']
# M38 subset score (3.): 0.8689921370880486
# ............
# Best model (M39) with 40 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration']
# M39 subset score (3.): 0.8689818889207375
# ............
# Best model (M40) with 41 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6']
# M40 subset score (3.): 0.8689276332904319
# ............
# Best model (M41) with 42 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4']
# M41 subset score (3.): 0.8688728733662752
# ............
# Best model (M42) with 43 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15']
# M42 subset score (3.): 0.8688720463994526
# ............
# Best model (M43) with 44 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1']
# M43 subset score (3.): 0.8688437598045342
# ............
# Best model (M44) with 45 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct']
# M44 subset score (3.): 0.8688249411244564
# ............
# Best model (M45) with 46 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8']
# M45 subset score (3.): 0.8687858214970072
# ............
# Best model (M46) with 47 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep']
# M46 subset score (3.): 0.8687680182027547
# ............
# Best model (M47) with 48 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20']
# M47 subset score (3.): 0.8687283558398334
# ............
# Best model (M48) with 49 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational']
# M48 subset score (3.): 0.8686939485068841
# ............
# Best model (M49) with 50 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration']
# M49 subset score (3.): 0.8686609894357152
# ............
# Best model (M50) with 51 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8']
# M50 subset score (3.): 0.8686153324897902
# ............
# Best model (M51) with 52 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8']
# M51 subset score (3.): 0.8685807868789894
# ............
# Best model (M52) with 53 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5']
# M52 subset score (3.): 0.8685390450282174
# ............
# Best model (M53) with 54 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9']
# M53 subset score (3.): 0.8683420832060348
# ............
# Best model (M54) with 55 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1']
# M54 subset score (3.): 0.8683058491036888
# ............
# Best model (M55) with 56 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar']
# M55 subset score (3.): 0.8681369089474995
# ............
# Best model (M56) with 57 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5']
# M56 subset score (3.): 0.8680560232628759
# ............
# Best model (M57) with 58 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11']
# M57 subset score (3.): 0.868024523148087
# ............
# Best model (M58) with 59 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7']
# M58 subset score (3.): 0.8680004106910131
# ............
# Best model (M59) with 60 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6']
# M59 subset score (3.): 0.8679970697986443
# ............
# Best model (M60) with 61 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11']
# M60 subset score (3.): 0.8679562675251065
# ............
# Best model (M61) with 62 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4']
# M61 subset score (3.): 0.8679211615785485
# ............
# Best model (M62) with 63 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2']
# M62 subset score (3.): 0.8677823039583318
# ............
# Best model (M63) with 64 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2']
# M63 subset score (3.): -168796469422056.78
# ............
# Best model (M64) with 65 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May']
# M64 subset score (3.): 0.8677822561035067
# ............
# Best model (M65) with 66 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5']
# M65 subset score (3.): 0.8677822179448343
# ............
# Best model (M66) with 67 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5', 'OperatingSystems_7']
# M66 subset score (3.): 0.8677822179448291
# ............
# Best model (M67) with 68 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5', 'OperatingSystems_7', 'Region_5']
# M67 subset score (3.): 0.8677822179448251
# ............
# Best model (M68) with 69 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5', 'OperatingSystems_7', 'Region_5', 'TrafficType_17']
# M68 subset score (3.): 0.8677822179448281
# ............
# Best model (M69) with 70 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5', 'OperatingSystems_7', 'Region_5', 'TrafficType_17', 'TrafficType_6']
# M69 subset score (3.): 0.8677606350650435
# ............
# Best model (M70) with 71 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5', 'OperatingSystems_7', 'Region_5', 'TrafficType_17', 'TrafficType_6', 'VisitorType_Returning_Visitor']
# M70 subset score (3.): 0.867760635065052
# ............
# Best model (M71) with 72 features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12', 'Month_Nov', 'TrafficType_14', 'Browser_13', 'TrafficType_18', 'Region_6', 'Month_Jul', 'TrafficType_7', 'Browser_10', 'OperatingSystems_1', 'TrafficType_13', 'TrafficType_3', 'Month_Feb', 'Month_Aug', 'OperatingSystems_3', 'ProductRelated_Duration', 'Administrative_Duration', 'Browser_6', 'Browser_4', 'TrafficType_15', 'Region_1', 'Month_Oct', 'TrafficType_8', 'Month_Sep', 'TrafficType_20', 'Informational', 'Informational_Duration', 'Region_8', 'Browser_8', 'Browser_5', 'TrafficType_9', 'TrafficType_1', 'Month_Mar', 'TrafficType_5', 'Browser_11', 'Region_7', 'OperatingSystems_6', 'TrafficType_11', 'Region_4', 'Region_2', 'Browser_2', 'Month_May', 'OperatingSystems_5', 'OperatingSystems_7', 'Region_5', 'TrafficType_17', 'TrafficType_6', 'VisitorType_Returning_Visitor', 'Weekend']
# M71 subset score (3.): 0.8677606350650506
#
#
# Best configuration has 24 features
# Features: ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other', 'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12']
# Total number of trained models: 3348

# %%
X_features_best = ['BounceRates', 'Administrative', 'ProductRelated', 'VisitorType_New_Visitor', 'PageValues', 'TrafficType_2', 'OperatingSystems_2', 'TrafficType_4', 'SpecialDay', 'Month_June', 'Browser_1', 'TrafficType_10', 'TrafficType_12', 'Month_Dec', 'OperatingSystems_8', 'VisitorType_Other',
                   'OperatingSystems_4', 'Browser_7', 'Region_9', 'Region_3', 'Browser_3', 'TrafficType_16', 'TrafficType_19', 'Browser_12']
X = training_set_no_missing[X_features_best].to_numpy()
y = training_set_no_missing['ExitRates'].to_numpy()

#splitting data
test_size = 0.1
test_seed = 50
# Split X and y into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=test_seed)
print("X_train.shape ", X_train.shape)
print("X_test.shape ", X_test.shape)


degree = list(range(1,3))
val_scores = np.zeros(len(degree))
# Validation
for i, d in enumerate(degree):
    model = Pipeline([('poly', PolynomialFeatures(degree=d, include_bias=False)),
                      ('linear', LinearRegression(fit_intercept=True))])
    scores = cross_val_score(model, X_train, y_train, scoring=r2_scorer, cv=5)
    val_scores[i] = np.mean(scores)

# Identifies which is the best degree
best_model_idx = np.argmax(val_scores)
best_degree = degree[best_model_idx]
# And the corresponding (best) validation score
best_val_score = val_scores[best_model_idx]
print("Best degree: ", best_degree,
      "\nVal score: ", best_val_score)
    
    
# Train again the Pipeline using the best parameter and the whole training set
model = Pipeline([('poly', PolynomialFeatures(degree=best_degree, include_bias=False)),
                  ('linear', LinearRegression(fit_intercept=True))])
# Note: we train on X_train_small + X_val
model = model.fit(np.concatenate([X_train]), np.concatenate([y_train]))
y_predict = model.predict(X_test)
test_score = r2_score(y_test, y_predict)

print("Test score:", test_score)
# Out:
# X_train.shape  (5819, 24)
# X_test.shape  (647, 24)
# Best degree:  1
# Val score:  0.8625488432279192
# Test score: 0.8435951870239029

# %%
X2 = training_set_missing[X_features_best].to_numpy()
y_predict2 = model.predict(X2)
y_predict2
# Out:
# array([0.04158924, 0.01832475, 0.0373027 , ..., 0.0383512 , 0.02675717,
#        0.0141067 ])
